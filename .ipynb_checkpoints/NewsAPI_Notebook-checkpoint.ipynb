# %% [markdown]
# # News API Experiment Notebook

# %% [markdown]
# #### Using Python Application Client

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='0bfec681c60e46bb93851e3788c3c58f')

# /v2/top-headlines
#top_headlines = newsapi.get_top_headlines(q='google')


# /v2/everything
#help(newsapi.get_everything)
company_all_articles = newsapi.get_everything(qintitle='"AMD"',
                                      language='en',
                                      sort_by='relevancy',
                                      page=2)

company_all_articles
# /v2/sources
#sources = newsapi.get_sources()
# Out:
# {'status': 'ok',
#  'totalResults': 1198,
#  'articles': [{'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Luke Larsen',
#    'title': 'The Razer Blade 14 somehow has both an AMD Ryzen 9 and a Nvidia RTX 3080',
#    'description': 'Razer says its new Blade 14 is the most powerful 14-inch laptop ever made, featuring both the Nvidia RTX 3080 and an AMD Ryzen 9 5900HX.',
#    'url': 'https://www.digitaltrends.com/computing/razer-blade-14-amd-ryzen-9-rtx-3080/',
#    'urlToImage': 'https://icdn.digitaltrends.com/image/digitaltrends/razer-blade-14-01.jpg',
#    'publishedAt': '2021-06-14T22:30:17Z',
#    'content': 'It’s clear that 14-inch gaming laptops are the next big thing, and with the Blade 14, Razer is officially in the game. Razer made the announcement at its E3 2021 press conference, along with the upda… [+2232 chars]'},
#   {'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Jacob Roach',
#    'title': 'Intel will feature DDR5 and PCIe 5.0 first, but AMD won’t be far behind',
#    'description': 'A new rumor shows the launch windows of new motherboard platforms for AMD and Intel, which confirms that Intel will be the first to feature DDR5 and PCIe 5.0.',
#    'url': 'https://www.digitaltrends.com/computing/intel-z690-z790-amd-x670-rumor/',
#    'urlToImage': 'https://icdn.digitaltrends.com/image/digitaltrends/asus-rog-maximus-xiii-extreme-glacial_2.jpg',
#    'publishedAt': '2021-06-16T18:41:30Z',
#    'content': 'A new rumor details the motherboard launch plans for AMD and Intel throughout 2022. According to the rumor, Intel is gearing up to launch its Z690 platform later this year for Alder Lake processors, … [+2510 chars]'},
#   {'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Jon Martindale',
#    'title': 'Why AMD FidelityFX Super Resolution is what DLSS always should have been',
#    'description': "AMD's Fidelity FX Super Resolution is almost here, and though it has a lot to prove, its broad and deep support make it a better upscaling technology than DLSS.",
#    'url': 'https://www.digitaltrends.com/computing/amd-fidelityfx-super-resolution-is-what-dlss-should-have-been/',
#    'urlToImage': 'https://icdn.digitaltrends.com/image/digitaltrends/fsrdlss.jpg',
#    'publishedAt': '2021-06-19T13:00:02Z',
#    'content': 'FidelityFX Super Resolution, or FSR, is AMD’s always expected, long-awaited, and almost-too-late, upscaling technology that enables higher frame rates at greater detail settings than simple native re… [+7095 chars]'},
#   {'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Chuong Nguyen',
#    'title': 'AMD Super Resolution is coming to the Xbox Series X. Here’s why that matters',
#    'description': "Microsoft's Xbox Series X is about to get better graphics performance with confirmed support for AMD's DLSS competitor called FidelityFX Super Resolution.",
#    'url': 'https://www.digitaltrends.com/computing/amd-super-resolution-could-improve-xbox-series-x/',
#    'urlToImage': 'https://icdn.digitaltrends.com/image/digitaltrends/fidelityfx-super-resolution-featured.jpg',
#    'publishedAt': '2021-06-04T21:45:12Z',
#    'content': 'After it was revealed that AMD’s competitor to Nvidia’s DLSS technology will be arriving on the company’s PC graphics cards later this month through a software update, it’s now confirmed that the com… [+3183 chars]'},
#   {'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Jacob Roach',
#    'title': 'The world’s fastest GPU, the AMD RX 6900 XT, just got faster',
#    'description': 'AMD released a new version of the RX 6900 XT that pushes the already powerful card even further, but you may not be able to buy one on its own.',
#    'url': 'https://www.digitaltrends.com/computing/amd-rx-6900-xt-liquid-cooled-edition-launch/',
#    'urlToImage': 'https://icdn.digitaltrends.com/image/digitaltrends/amd-rx6900xtlc.jpg',
#    'publishedAt': '2021-06-16T17:39:50Z',
#    'content': 'After leaks from the past few days, AMD has officially launched the RX 6900 XT Liquid Edition. As the name implies, this is an RX 6900 XT with a built-in liquid cooler, but extra cooling isn’t all th… [+2150 chars]'},
#   {'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Jacob Roach',
#    'title': 'You can finally try our AMD Super Resolution in one of the few launch titles',
#    'description': 'AMD released FidelityFX Super Resolution for seven games, offering up to 2x resolution scaling across multiple generations of AMD and Nvidia GPUs.',
#    'url': 'https://www.digitaltrends.com/computing/amd-launches-fidelityfx-super-resolution/',
#    'urlToImage': 'https://icdn.digitaltrends.com/image/digitaltrends/godfall-multiplayer-combat.jpg',
#    'publishedAt': '2021-06-22T13:00:38Z',
#    'content': 'Following an announcement at Computex 2021, AMD has officially released its FidelityFX Super Resolution (FSR). According to AMD, FSR can achieve up to a 2.4x increase in performance versus native 4K,… [+3133 chars]'},
#   {'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Jacob Roach',
#    'title': 'How the AMD RX 6800 XT runs 9% faster than it did at launch',
#    'description': 'An analysis of performance between 2020 and 2021 shows big improvements on AMD cards, with some cards performing as much as 9% better than at launch.',
#    'url': 'https://www.digitaltrends.com/computing/amd-rx-6800-xt-9-percent-faster-than-launch/',
#    'urlToImage': 'https://icdn.digitaltrends.com/image/digitaltrends/amd-radeon-rx-6000.jpg',
#    'publishedAt': '2021-06-29T18:25:52Z',
#    'content': 'At launch, AMD’s RDNA 2-powered RX 6000 cards performed slightly worse than Nvidia’s RTX 30-series range. The RX 6900 XT ran about 10% slower than the competing RTX 3090, and the RX 6800 XT ran about… [+2466 chars]'},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'Sean Endicott',
#    'title': 'AMD hits 30% CPU market share in latest Steam Survey',
#    'description': "AMD lags behind NVIDIA in total CPU market share among gamers, but it's steadily closing the gap.\n\n\n\nWhat you need to know\n\n\nAMD reached 30% CPU market share among gaming PCs in the latest Steam Survey.\nThe success of Zen 3 Ryzen 5000 series processors likely…",
#    'url': 'https://www.windowscentral.com/amd-tops-30-cpu-share-among-gamers-latest-steam-survey',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2021/01/amd-ryzen-9-5950x-motherboard.jpg',
#    'publishedAt': '2021-06-08T14:59:02Z',
#    'content': 'AMD continues to trend upwards in terms of market share among gamers. According to the latest Steam Survey, AMD CPUs just surpassed 30% market share among gaming PCs. NVIDIA still has a market share … [+1477 chars]'},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'Tyler Colp',
#    'title': 'The best coolers for your new AMD Ryzen 7 5800X',
#    'description': "So you're building a new PC and you're trying to find the best CPU cooler for the AMD Ryzen 5800X. AMD's powerhouse CPU doesn't come with a stock cooler, so you'll have to look for outside cooling solutions, and ones that will work with popular cases. It all …",
#    'url': 'https://www.windowscentral.com/best-cpu-coolers-amd-ryzen-7-5800x',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2020/11/nzxt-kraken-x73-aio-rgb-fans.jpg',
#    'publishedAt': '2021-07-01T19:00:02Z',
#    'content': "Best\r\nCPU coolers for AMD Ryzen 7 5800X\r\nWindows Central2021\r\nSo you're building a new PC and you're trying to find the best CPU cooler for the AMD Ryzen 5800X. AMD's powerhouse CPU doesn't come with… [+1877 chars]"},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'Sean Endicott',
#    'title': 'AMD FidelityFX Super Resolution launches to compete with NVIDIA DLSS',
#    'description': "After months of teasing and previews, AMD's FidelityFX Super Resolution is finally here.\n\n\n\nWhat you need to know\n\n\nAMD's FidelityFX Super Resolution is available starting today.\nThe feature boosts frame rates and resolution of games with spatial upscaling.\nF…",
#    'url': 'https://www.windowscentral.com/amd-launches-fidelityfx-super-resolution-its-answer-nvidia-dlss',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2021/01/asus-tuf-gaming-rx-6800-hero-02.jpg',
#    'publishedAt': '2021-06-22T13:51:16Z',
#    'content': "Source: Windows Central\r\n<ul><li>AMD's FidelityFX Super Resolution is available starting today.</li><li>The feature boosts frame rates and resolution of games with spatial upscaling.</li><li>Fidelity… [+2048 chars]"},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'Tyler Colp',
#    'title': 'These are the best coolers for AMD Ryzen 5 5600X',
#    'description': "The best CPU coolers for the AMD Ryzen 5 5600X are a little tricky to find. The CPU itself isn't super power hungry compared to its AMD Ryzen brothers, so it doesn't get considerably hot, but if you want to push it further with a specific build or overclock, …",
#    'url': 'https://www.windowscentral.com/best-cpu-coolers-amd-ryzen-5-5600x',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2020/01/nzxt-kraken-z73-hero.jpg',
#    'publishedAt': '2021-06-30T11:00:02Z',
#    'content': "Best\r\nCPU coolers for AMD Ryzen 5 5600X\r\nWindows Central2021\r\nThe best CPU coolers for the AMD Ryzen 5 5600X are a little tricky to find. The CPU itself isn't super power hungry compared to its AMD R… [+2340 chars]"},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'Tyler Colp',
#    'title': 'Is the AMD Ryzen 7 5800X the best for gaming?',
#    'description': "Best answer: No. The Ryzen 7 5800X is complete overkill for gaming and not even the best value among AMD's lineup of modern CPUs.\n\nMore cores don't equal better gaming\n\nA fairly common misconception among gamers is that more cores means better gaming performa…",
#    'url': 'https://www.windowscentral.com/amd-ryzen-7-5800x-good-gaming',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2020/12/amd-ryzen-7-5800x-box-01.jpg',
#    'publishedAt': '2021-06-29T11:30:02Z',
#    'content': "Source: Windows Central\r\nBest answer: No. The Ryzen 7 5800X is complete overkill for gaming and not even the best value among AMD's lineup of modern CPUs.\r\nMore cores don't equal better gaming\r\nA fai… [+2793 chars]"},
#   {'source': {'id': None, 'name': 'Rock Paper Shotgun'},
#    'author': 'Will Judd',
#    'title': 'This half-price MSI B550 motherboard could be the heart of your next AMD PC',
#    'description': "If you're planning to build a new PC or upgrade an old one to run AMD's latest Ryzen processors, this deal is for you. The MSI MAG B550M Bazooka is one of the best recent AMD motherboards, and it's been heavily discounted at Amazon today. It normally retails …",
#    'url': 'https://www.rockpapershotgun.com/at-half-price-this-msi-b550-motherboard-could-form-the-heart-of-your-next-amd-pc',
#    'urlToImage': 'https://assets2.rockpapershotgun.com/bazooka.jpg/BROK/resize/1920%3E/format/jpg/quality/80/bazooka.jpg',
#    'publishedAt': '2021-06-02T17:47:55Z',
#    'content': "If you're planning to build a new PC or upgrade an old one to run AMD's latest Ryzen processors, this deal is for you. The MSI MAG B550M Bazooka is one of the best recent AMD motherboards, and it's b… [+2390 chars]"},
#   {'source': {'id': None, 'name': 'Phandroid - News for Android'},
#    'author': 'Tyler Lee',
#    'title': 'Samsung’s Exynos chipset with AMD graphics is destroying the competition',
#    'description': 'According to leaked benchmarks, it seems that Samsung’s upcoming Exynos processor with AMD graphics is handily beating out the competition.\nThe post Samsung’s Exynos chipset with AMD graphics is destroying the competition first appeared on Phandroid.',
#    'url': 'https://phandroid.com/2021/06/29/samsungs-exynos-chipset-with-amd-graphics-is-destroying-the-competition/',
#    'urlToImage': 'https://phandroid.com/wp-content/uploads/2019/06/amd-640x357.jpg',
#    'publishedAt': '2021-06-29T07:25:57Z',
#    'content': 'Samsung’s efforts at making their own chipsets have been a bit of a mixed bag. For a while it looked like they were on par with Qualcomm, then for a period of time, they started to fall behind hard, … [+1336 chars]'},
#   {'source': {'id': None, 'name': 'AppleInsider'},
#    'author': 'news@appleinsider.com (Amber Neely)',
#    'title': 'AMD announces W6600, W6800 PCI-E GPU compatible with Mac Pro, eGPU',
#    'description': 'The new Radeon Pro W6800 graphics card is designed to be used in high-powered workstations such as the Intel-based Mac Pro.AMD has unveiled its new AMD Radeon PRO W6000 series workstation graphics PCI-E GPU cards, geared for professional use. AMD says that th…',
#    'url': 'https://appleinsider.com/articles/21/06/09/amd-announces-w6600-w6800-pci-e-gpu-compatible-with-mac-pro-egpu',
#    'urlToImage': 'https://photos5.appleinsider.com/gallery/42524-82497-yeaher-xl.jpg',
#    'publishedAt': '2021-06-09T13:24:39Z',
#    'content': 'The new Radeon Pro W6800 graphics card is designed to be used in high-powered workstations such as the Intel-based Mac Pro.\r\nAMD has unveiled its new AMD Radeon PRO W6000 series workstation graphics … [+1847 chars]'},
#   {'source': {'id': None, 'name': 'GameSpot'},
#    'author': 'Darryn Bonthuys',
#    'title': 'Forspoken Gets An AMD FSR Upgrade In New Gameplay Trailer',
#    'description': "AMD's new FidelityFX Super Resolution trailer has gone live, and inside of the showreel for the company's answer to Nvidia's DLSS performance-enhancing graphics technology is new gameplay footage of Forspoken. You can see some new and extended footage in the …",
#    'url': 'https://www.gamespot.com/articles/forspoken-gets-an-amd-fsr-upgrade-in-new-gameplay-trailer/1100-6493186/',
#    'urlToImage': 'https://www.gamespot.com/a/uploads/screen_kubrick/1601/16018044/3847757-forspoken.jpg',
#    'publishedAt': '2021-06-23T14:13:00Z',
#    'content': "AMD's new FidelityFX Super Resolution trailer has gone live, and inside of the showreel for the company's answer to Nvidia's DLSS performance-enhancing graphics technology is new gameplay footage of … [+1363 chars]"},
#   {'source': {'id': None, 'name': 'HYPEBEAST'},
#    'author': 'info@hypebeast.com (HYPEBEAST), HYPEBEAST',
#    'title': 'Razer Unveils Ultra-Thin and Super-Fast AMD Gaming Laptop',
#    'description': 'Razer, the Singaporean-American tech company known for its gaming hardware, unveiled an all-new and ultra-thin gaming laptop at its E3 2021 showcase on Monday.Known as the Razer Blade 14, the powerful 14-inch computer is being hailed as "the ultimate AMD gami…',
#    'url': 'https://hypebeast.com/2021/6/razer-blade-14-amd-gaming-laptop-e3',
#    'urlToImage': 'https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2021%2F06%2FRazer-Unveils-Ultra-Thin-and-Super-Fast-AMD-Gaming-Laptop-tw.jpg?w=960&cbr=1&q=90&fit=max',
#    'publishedAt': '2021-06-14T23:30:29Z',
#    'content': 'Razer, the Singaporean-American tech company known for its gaming hardware, unveiled an all-new and ultra-thin gaming laptop at its E3 2021 showcase on Monday.\r\nKnown as the Razer Blade 14, the power… [+1954 chars]'},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'Tyler Colp',
#    'title': 'Is the AMD Ryzen 9 5900X the best CPU for games?',
#    'description': 'Best answer: Yes, the AMD Ryzen 9 5900X is an excellent choice for gaming, if a bit pricey. Its 12 cores might be a little overkill for gaming, but its raw processing speed puts it at the top against any and all competition.\n\nWhy is the AMD Ryzen 9 5900X good…',
#    'url': 'https://www.windowscentral.com/amd-ryzen-9-5900x-good-gaming',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2018/08/ryzen-motherboard-aorus-1.jpg',
#    'publishedAt': '2021-06-15T19:00:02Z',
#    'content': 'Source: Windows Central\r\nBest answer: Yes, the AMD Ryzen 9 5900X is an excellent choice for gaming, if a bit pricey. Its 12 cores might be a little overkill for gaming, but its raw processing speed p… [+3239 chars]'},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'Richard Devine',
#    'title': "Yes, you're good with a TPM if you use an AMD PC",
#    'description': "Best answer: Absolutely, and your PC might already have it. In the BIOS on AMD PCs it's known as fTPM.\n\nAMD users and TPMs\n\n\n\nTrusted Platform Modules (TPMs) are a hot topic because of Microsoft's requirements for them in Windows 11. It's also led to a mild p…",
#    'url': 'https://www.windowscentral.com/can-i-run-trusted-platform-module-tpm-amd-computers',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2021/06/amd-ftpm-bios.jpg',
#    'publishedAt': '2021-06-30T12:00:02Z',
#    'content': "Trusted Platform Modules (TPMs) are a hot topic because of Microsoft's requirements for them in Windows 11. It's also led to a mild panic and scalping of TPM units at online retailers. If you're usin… [+1274 chars]"},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'Sean Endicott',
#    'title': 'AMD expands FidelityFX Super Resolution support to include RX 470 & RX 480',
#    'description': "AMD's FidelityFX Super Resolution will help give life to some older graphics cards.\n\n\n\nWhat you need to know\n\n\nAMD's FidelityFX Super Resolution will work with the RX 470 and RX 480 GPUs.\nOriginally, RX 500-series GPUs were the oldest cards that would be supp…",
#    'url': 'https://www.windowscentral.com/amd-extends-fidelityfx-super-resolution-older-gpus',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2017/05/xfx-rx-480-rs.jpg',
#    'publishedAt': '2021-06-04T11:16:04Z',
#    'content': 'AMD recently showed off its FidelityFX Super Resolution (FSR) technology at Computex 2021. FSR is a digital upscaling technology that makes games look and perform better without needing as much proce… [+1165 chars]'}]}

# %%
# /v2/sources
business_news_sources_response = newsapi.get_sources(category='business', language = 'en')
business_news_sources_response
# Out:
# {'status': 'ok',
#  'sources': [{'id': 'australian-financial-review',
#    'name': 'Australian Financial Review',
#    'description': 'The Australian Financial Review reports the latest news from business, finance, investment and politics, updated in real time. It has a reputation for independent, award-winning journalism and is essential reading for the business and investor community.',
#    'url': 'http://www.afr.com',
#    'category': 'business',
#    'language': 'en',
#    'country': 'au'},
#   {'id': 'bloomberg',
#    'name': 'Bloomberg',
#    'description': 'Bloomberg delivers business and markets news, data, analysis, and video to the world, featuring stories from Businessweek and Bloomberg News.',
#    'url': 'http://www.bloomberg.com',
#    'category': 'business',
#    'language': 'en',
#    'country': 'us'},
#   {'id': 'business-insider',
#    'name': 'Business Insider',
#    'description': 'Business Insider is a fast-growing business site with deep financial, media, tech, and other industry verticals. Launched in 2007, the site is now the largest business news site on the web.',
#    'url': 'http://www.businessinsider.com',
#    'category': 'business',
#    'language': 'en',
#    'country': 'us'},
#   {'id': 'business-insider-uk',
#    'name': 'Business Insider (UK)',
#    'description': 'Business Insider is a fast-growing business site with deep financial, media, tech, and other industry verticals. Launched in 2007, the site is now the largest business news site on the web.',
#    'url': 'http://uk.businessinsider.com',
#    'category': 'business',
#    'language': 'en',
#    'country': 'gb'},
#   {'id': 'financial-post',
#    'name': 'Financial Post',
#    'description': 'Find the latest happenings in the Canadian Financial Sector and stay up to date with changing trends in Business Markets. Read trading and investing advice from professionals.',
#    'url': 'http://business.financialpost.com',
#    'category': 'business',
#    'language': 'en',
#    'country': 'ca'},
#   {'id': 'fortune',
#    'name': 'Fortune',
#    'description': 'Fortune 500 Daily and Breaking Business News',
#    'url': 'http://fortune.com',
#    'category': 'business',
#    'language': 'en',
#    'country': 'us'},
#   {'id': 'the-wall-street-journal',
#    'name': 'The Wall Street Journal',
#    'description': 'WSJ online coverage of breaking news and current headlines from the US and around the world. Top stories, photos, videos, detailed analysis and in-depth reporting.',
#    'url': 'http://www.wsj.com',
#    'category': 'business',
#    'language': 'en',
#    'country': 'us'}]}

# %%
Sources = ", ".join([response['name'] for response in business_news_sources_response['sources']])
sources
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c1720af8fe16> in <module>
#       1 Sources = ", ".join([response['name'] for response in business_news_sources_response['sources']])
# ----> 2 sources
#
# NameError: name 'sources' is not defined

# %%
company_business_articles_response = newsapi.get_everything(q='Google',
                                      language='en',
                                      sort_by='relevancy',
                                      sources = Sources)

company_business_articles = [article for article in company_business_articles_response['articles']]
company_business_articles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6b303cb0a4bf> in <module>
#       2                                       language='en',
#       3                                       sort_by='relevancy',
# ----> 4                                       sources = Sources)
#       5
#       6 company_business_articles = [article for article in company_business_articles_response['articles']]
#
# NameError: name 'Sources' is not defined
